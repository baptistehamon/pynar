# %%
import computeIndicator as CP
import pandas as pd 
import xarray as xr
import datetime as dt 
import numpy as np

# %%
ModelTas=xr.open_dataset("../../../Encadrement/These/Jing/data/climate/VCSN_Tmean5k_1972-2020.nc")

# %%
ModelTas
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 17898, longitude: 243, latitude: 260)
# Coordinates:
#   * time       (time) datetime64[ns] 1972-01-01T00:09:00 ... 2020-12-31T09:00:00
#   * longitude  (longitude) float64 166.4 166.5 166.5 166.6 ... 178.4 178.5 178.5
#   * latitude   (latitude) float64 -34.38 -34.42 -34.47 ... -47.22 -47.28 -47.33
# Data variables:
#     tmean      (time, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.8 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Mon Dec 05 09:43:33 2022: cdo expr,tmean=(tmin+tmax)/2 dum_...
#     Description:  Virtual climate station data,\n convert to grid from xxxx_v...
#     Author:       Abha Sood,
#     Date:         Created on Fri Mar 22 02:36:59 2019 UTC
#     CDO:          Climate Data Operators version 1.9.8 (https://mpimet.mpg.de...

# %%
dataTemp=ModelTas.sel(time=slice('1980','2010'))
dataTemp=dataTemp-273.15

# %%
test=CP.compute_indicator_netcdf(climate_data=dataTemp, NameIndicator="hsfreq",threshold=20,varName="tmean", two_years_culture=True, start_stage=1, end_stage=365)
# Out:
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010

# %%
test.isel(year=1).hsfreq.plot()
